# %%
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

# %%
from pdfreader import SimplePDFViewer
import PIL.ImageOps 
import matplotlib.pyplot as plt
fd = open("pdfs\Sem3 result.pdf", "rb")
viewer = SimplePDFViewer(fd)

viewer.render()
img = viewer.canvas.images['Im2']

print(img)
# this displays ICCBased 4 RelativeColorimetric
print(img.ColorSpace[0], img.ColorSpace[1].N, img.Intent)

pil_image = img.to_Pillow()
plt.imshow(pil_image)
plt.show()
# pil_image = pil_image.convert("RGB")
pil_image.save("test.png")
# inverted = PIL.ImageOps.invert(pil_image)


# inverted.save("sample.png")
# Out:
# <Stream:len=639432,data=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00\xc8\x00\xc8\x00\x00\xff\xdb\x00C\x00 ...'>
# ICCBased 3 None

# %%
import cv2 
img = cv2.imread('test.png')

# %%
text = pytesseract.image_to_string(img)
print(text)
# Out:
# SIES GRADUATE SCHOOL OF TECHNOLOGY
# HANDRASEKARENDRA SARASWATI VIDYAPURAM,SECTOR V,NERUL, NAV] MUMBAL-4
# (ON BEHALF OF UNIVERSITY OF MUMBAI)
#
# SECOND YEAR LT. ENGINEERING SEMESTER II] (R- 19) CHOICE BASED (CBCGS) Examination held in DECEMBER 2020
#
# —1re301.—sTC302_——STTC303—sTC304 ITC305. ITL301 ITL302 rele ITL304 ITM301
# Engineering Data Structure Database Principle Of Paradigms And Data Structure SQL Lab Computer Java Lab (s B. Mini Pr oject - 1 Outof
# Mathematics-I11 And Analysis Management Communication Computer Lab Programming L) A For Front uw o
# System Programming Paradigms Lab End / Backend 775
# Fundamentals Application
# _ _ 7 a a i _ 7 4 - Using Java
# Sr. Name of the Student | |
# No. SE IA TOTTW SE JA TOT SE JA TOT SE IA TOT SE IA TOT TW P/O TOT TW P/O TOT TW P/O TOT TW P/O TOT TW P/O TOT Result
# | | |
# Seat No. Maximum 80 20 100 25 80 20 100 80 20 100 80 20 100 80 20 100 25 25 50 25 25 50 25 25 50 30 25 2550
# Roll No. Minimum 32 8 40 10 32 8 40 32° 8 40 32 8 40 32 8 40 10 10 20 10 10 20,10 10 20 20 10 10 20. EC ECG GPA
# —— pe ee | | oa eee | __| | | a 1 | = | | att
# 1 /AAKANSHA RAMESH "Marks 66 20 86 23 67 19 86 70/16 86 75 20 95 63 17 80 22 21 43 23 22 45 23 23 46 | 46 24 | 23 | 47 | 683
# | Obtained) | |
# {—— 4 4 —= = = L = — 4 4 4 2 es 4 = 4
# | Grade] Oo| o|o/o/lolojolo/ojoj/o/oloialojoj/o;olo/lo/oj/o/ololo/o!lo P
# 42285001 GradePt| | | 10 | 10 10) 0 | 10 | | 10 | 10 | 10 10 |
# | 7 Credit Pt. | 3 | 1 | 3 | | 3 | 3 3 | 1 [1 | 1 23 230 10
# | | Ba CP*GP | 30 | 10 | 30) | 30 || 30 [30 | 0 10 | 10 |
# 2| AAQIB FAROOQ - Marks) 56/18 74/10 | 51/16 67, 51 15 66 67 | 17 84/37 | 17 | 54) 11 | 16 | 27/ 16 | 15) 31/ 16 | 15) 31| 12 499
# Obtained | | | |
# Grade] B| O| Bl P| ci{[olc{c{alc|lololo[zelo|p|[Peplel[pi[clc{[ciclc{cle P
# 42233002 Grade EG) 8 4 7 [ 7 10 6 | 6 7 | a
# Credit Pt. | 3 [1 3 | 3 | 3 | 3 1 1 1 23 162 7.04
# ESI CP*GP 24] 4 2| | 21 | 30 | 18 | 6 | 7 | 7 4
# 3, SHINDE ABHISHEK SANJAYKUMAR Marks) 43 | 20 | 63 22 | 65 | 19 | 84) 59 | 17 | 76/73 | 18 / 91/56 18 | 74/ 22 | 19 | 41] 21 | 21 | 42/ 22 / 18 | 40 | 21 623
# Obtained | | | |
# | = = = 4 4 a 1 — ——
# Grade) D| OO Clo|o/o0 0 Bio A 0.0/0) B/0/B}/O}A,0/0, 0,0'0/B 0/0 P
# | 42233003 Grade Pt.| 7_| 10 10) 2 ___ 10 8 | 10 10 | | 10 | |
# Credit Pt.) 31 t3] | 3 ME ni 1 1 | 1 23 212 9.22
# _ 11949008 CP*GP| 21 | 10 | [30; | 27 | 30 | 24 10 10 | | 10 _ |
# SINGH ABHISHEK VIRENDRA Marks) 53 | 20 73 20 56 18 | 74 51 17) 68/71. 19 | 90| 51 | 19 | 70| 20 | 20) 40| 22 | 21 | 43/ 21 | 18 39) 19 602
# Obtained | | | | | |
# — — 4 = 1 = 4 4 |
# Grade C O81 BlO!|B/O!]B!clolclolo\|o\|c!o Bi.0,0,0,0/0/0°.0'B AjA P
# is | | o | O y | 9 i
# | 42233004 | Grade Ft | 8 | 10] _ 8 7 | 10 | 8 10 ee! Soe | 9 |
# | | Credit Pt. | 3 | 1 | | 3 | 3 | | 3 ee a 1 [1] 23 202 8.78 |
# 119A3004 | __CP*GP| 24 10 24 | - | 24 | 30 | | , 24] _10 10 | | 9 _|
# (5 /ANUPRIYA SELVARAJ "| Marks! 6420 84-20 55:18 | 73 87 14 71/70 19 | 89 48 | 17 | 65 | 22 | 20 | 42 22 19 41) 22 20) 42 21 619
# | Obtained | | | | | | | | |
# | Grade] O| 0 0/01c, 0/B[BiBiBlololo/clolcio/o,o/olaloljo ojo] P
# [ae i i = ] t T T 4 1 | = | = ] =| |
# 42233005 _ Grade Pt. 1010 | 8) | 8 | 10 | 10 10 | 10 |
# CreditPt, 3 [3] a || 3 | Z 1 | | 1 | 1 23 209 9.09
# enue | cp*eP| [|| 30 | 24] | 24 | | 30 | 10 | [10 | 10 : |
#
# P - Passes. NULL-Null & Void.~ Dys xia Benefit/Person wil
#
# 0.229, @:0.5042, *:0.5045. ADC - Admission Cancelled, RR-Reserved, -- : s in Theory or Pra PRY - Provisional. RCC - 0.5050, A.ABS - Absent. F - Fi
# G: Grade, GP : GradePoint, C : Credits, CP : Credit Points, ECG : Sum of product of credits & grades, EC : Sum of Creditpoints, GPA : ECG / EC
# (Marks/Grade/GradePoint] : [>=80 and <=100/0/10] [>=75 and <80/A/ 9] [x=70 and <75/B/8] [>=60 and <70/C/7] [>=50 and<60/D/6] [>=45 and <50/
#
# Entered by: ° WV Read by: a Checked by: the P
#
# (>=40 and <45/P/4] [>=0 and <40/F/0]
#
# OL OF TECHNOLOGY
#
# eel SARASWATHY VIDYAPURAM

# %%
import easyocr

reader = easyocr.Reader(['en'],gpu=False)
result = reader.readtext("test.png")
print(result)
# Out:
# WARNING:easyocr.easyocr:Using CPU. Note: This module is much faster with a GPU.
# [([[173, 96], [198, 96], [198, 120], [173, 120]], '0', 0.9816855125213273), ([[1698, 83], [1768, 83], [1768, 133], [1698, 133]], '2 ?', 0.24374994714915588), ([[78, 85], [111, 85], [111, 201], [78, 201]], '1', 0.06698998164189618), ([[207, 96], [231, 96], [231, 213], [207, 213]], '1', 0.7257886220014029), ([[543, 124], [572, 124], [572, 149], [543, 149]], '07', 0.49243464778014245), ([[801, 124], [826, 124], [826, 149], [801, 149]], 'A', 0.9882820440041975), ([[1054, 124], [1084, 124], [1084, 149], [1054, 149]], '@', 0.08133176437718248), ([[1310, 124], [1340, 124], [1340, 149], [1310, 149]], 'N', 0.9996629045422765), ([[176, 134], [200, 134], [200, 203], [176,